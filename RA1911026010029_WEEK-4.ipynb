# %% [markdown]
# # SET-3
# ### CONVERT THE FOLLOWING MANUAL FORM INTO DIGITAL MODE USING TKINTER
# **DONE BY:
# <br>Thejaswin.S
# <br>RA1911026010029
# <br>CSE-AIML K1**

# %% [markdown]
# ### Image of form

# %%
from IPython.display import Image
Image(filename='form.png')

# %% [markdown]
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>

# %% [markdown]
# ### After pressing submit button user will get notified whether response is saved successfully or not

# %%
from IPython.display import Image
Image(filename='msgbox.png')

# %% [markdown]
# ### After submit button is pressed the form is reset for next response submission

# %%
from IPython.display import Image
Image(filename='after_sub.png')

# %% [markdown]
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>

# %% [markdown]
# ### The data entered in form is stored in Excel sheet (.xlsx)

# %%
from IPython.display import Image
Image(filename='excel.png')

# %% [markdown]
# # CODE

# %%
from openpyxl import *        
from tkinter import *
from tkinter import messagebox 
#wb=Workbook()
wb = load_workbook('excel.xlsx') 

sheet = wb.active 

def deleteall():
    v1.set(0)
    v2.set(0)
    v3.set(0)
    v4.set(0)
    v5.set(0)
    v6.set(0)
    v7.set(0)
    v8.set(0)
    v9.set(0)
    v10.set(0)
    v11.set(0)
    v12.set(0)
    v13.set(0)
    v14.set(0)
    v15.set(0)
    v16.set(0)
    v17.set(0)
    v18.set(0)
    v19.set(0)
    v20.set(0)
    v21.set(0)
    name_entry.delete(0,END)
    name_entry.insert(0,"ENTER PLATE NUM")
    name_entry01.delete(0,END)
    name_entry1.delete(0,END)
    name_entry2.delete(0,END)
    name_entry2.insert(0,"SPECIFY")
    name_entry3.delete(0,END)
    name_entry4.delete(0,END)
    name_entry5.delete(0,END)
    name_entry6.delete(0,END)
    name_entry7.delete(0,END)
    name_entry8.delete(0,END)
    name_entry9.delete(0,END)
    name_entry10.delete(0,END)
    name_entry11.delete(0,END)
    name_entry12.delete(0,END)
    name_entry13.delete(0,END)
    name_entry14.delete(0,END)
    name_entry15.delete(0,END)
    name_entry16.delete(0,END)
    name_entry17.delete(0,END)
    name_entry018.delete(0,END)
    name_entry18.delete(0,END)
    name_entry19.delete(0,END)
    name_entry20.delete(0,END)
    name_entry21.delete(0,END)
    name_entry22.delete(0,END)
    name_entry23.delete(0,END)
    name_entry24.delete(0,END)

def excel(): 

    sheet.column_dimensions['A'].width = 30
    sheet.column_dimensions['B'].width = 30
    sheet.column_dimensions['C'].width = 30
    sheet.column_dimensions['D'].width = 30
    sheet.column_dimensions['E'].width = 30
    sheet.column_dimensions['F'].width = 30
    sheet.column_dimensions['G'].width = 30
    sheet.column_dimensions['H'].width = 30
    sheet.column_dimensions['I'].width = 30
    sheet.column_dimensions['J'].width = 30
    sheet.column_dimensions['K'].width = 30
    sheet.column_dimensions['L'].width = 30
    sheet.column_dimensions['M'].width = 30
    sheet.column_dimensions['N'].width = 30
    sheet.column_dimensions['O'].width = 30
    sheet.column_dimensions['P'].width = 30
    sheet.column_dimensions['Q'].width = 30
    sheet.column_dimensions['R'].width = 30
    sheet.column_dimensions['S'].width = 30
    sheet.column_dimensions['T'].width = 30
    sheet.column_dimensions['U'].width = 30
    sheet.column_dimensions['V'].width = 30
    sheet.column_dimensions['W'].width = 30
    sheet.column_dimensions['X'].width = 30
    sheet.column_dimensions['Y'].width = 30
    sheet.column_dimensions['Z'].width = 30
    sheet.column_dimensions['AA'].width = 30
  

    sheet.cell(row=1, column=1).value = "License plate no."
    sheet.cell(row=1, column=2).value = "Seating capacity"
    sheet.cell(row=1, column=3).value = "ARO CALL letter"
    sheet.cell(row=1, column=4).value = "Other"
    sheet.cell(row=1, column=5).value = "Owner's name"
    sheet.cell(row=1, column=6).value = "telephone no."
    sheet.cell(row=1, column=7).value = "SSN no."
    sheet.cell(row=1, column=8).value = "Co.owner's name"
    sheet.cell(row=1, column=9).value = "telephone no."
    sheet.cell(row=1, column=10).value = "SSN no."
    sheet.cell(row=1, column=11).value = "Business jurisdiction"
    sheet.cell(row=1, column=12).value = "owner's address"
    sheet.cell(row=1, column=13).value = "City"
    sheet.cell(row=1, column=14).value = "State"
    sheet.cell(row=1, column=15).value = "Zip code"
    sheet.cell(row=1, column=16).value = "Co.owner's address"
    sheet.cell(row=1, column=17).value = "City"
    sheet.cell(row=1, column=18).value = "State"
    sheet.cell(row=1, column=19).value = "Zip code"
    sheet.cell(row=1, column=20).value = "Owner's email"
    sheet.cell(row=1, column=21).value = "CO.owner's email"
    sheet.cell(row=1, column=22).value = "Location"
    sheet.cell(row=1, column=23).value = "date "
    sheet.cell(row=1, column=24).value = "reg mail address"
    sheet.cell(row=1, column=25).value = "City"
    sheet.cell(row=1, column=26).value = "State"
    sheet.cell(row=1, column=27).value = "Zip code"
    
    
def insert(): 

    if True :
        current_row = sheet.max_row 
        current_column = sheet.max_column 

        sheet.cell(row=current_row + 1, column=1).value = name_entry.get() 
        sheet.cell(row=current_row + 1, column=2).value = name_entry01.get() 
        sheet.cell(row=current_row + 1, column=3).value = name_entry1.get() 
        sheet.cell(row=current_row + 1, column=4).value = name_entry2.get() 
        sheet.cell(row=current_row + 1, column=5).value = name_entry3.get() 
        sheet.cell(row=current_row + 1, column=6).value = name_entry4.get() 
        sheet.cell(row=current_row + 1, column=7).value = name_entry5.get()
        sheet.cell(row=current_row + 1, column=8).value = name_entry6.get()
        sheet.cell(row=current_row + 1, column=9).value = name_entry7.get()
        sheet.cell(row=current_row + 1, column=10).value =name_entry8.get()
        sheet.cell(row=current_row + 1, column=11).value =name_entry9.get()
        sheet.cell(row=current_row + 1, column=12).value =name_entry10.get()
        sheet.cell(row=current_row + 1, column=13).value =name_entry11.get()
        sheet.cell(row=current_row + 1, column=14).value =name_entry12.get()
        sheet.cell(row=current_row + 1, column=15).value =name_entry13.get()
        sheet.cell(row=current_row + 1, column=16).value =name_entry14.get()
        sheet.cell(row=current_row + 1, column=17).value =name_entry15.get()
        sheet.cell(row=current_row + 1, column=18).value =name_entry16.get()
        sheet.cell(row=current_row + 1, column=19).value =name_entry17.get()
        sheet.cell(row=current_row + 1, column=20).value =name_entry018.get()
        sheet.cell(row=current_row + 1, column=21).value =name_entry18.get()
        sheet.cell(row=current_row + 1, column=22).value =name_entry19.get()
        sheet.cell(row=current_row + 1, column=23).value =name_entry20.get()
        sheet.cell(row=current_row + 1, column=24).value =name_entry21.get()
        sheet.cell(row=current_row + 1, column=25).value =name_entry22.get()
        sheet.cell(row=current_row + 1, column=26).value =name_entry23.get()
        sheet.cell(row=current_row + 1, column=27).value =name_entry24.get()
        
        # save the file 
        wb.save('excel.xlsx') 
        messagebox.showinfo("showinfo", "Response is saved successfully")
        deleteall()     

root=Tk()
#frame = Frame(width=910, height=520, bg="", colormap="new")
#frame.pack()
root.geometry('910x640')
root.title("Digital Form")
root.configure(bg='white')
reg_info = Label(root,text = "REGISTRATION INFORMATION",width='910',font= ("ariel",11,"bold"),fg = "black",bg='lightgrey')
reg_info.place(x=470,y=12,anchor='center')
reg_period=Label(root,text="Registration Period: ",font=("ariel",11,"bold"),bg='white')
reg_period.place(x=0,y=25)
reg_period=Label(root,text="(check one)",font=("ariel",9),bg='white')
reg_period.place(x=145,y=25)
v1=IntVar()
v2=IntVar()
v3=IntVar()
cb1=Checkbutton(root,text='One Year', variable=v1,onvalue=1, bg='white',offvalue=0)
cb1.place(x=240,y=25)
cb2=Checkbutton(root,text='Two Years ($2 discount applies)', variable=v2,onvalue=1,bg='white', offvalue=0)
cb2.place(x=350,y=25)
cb3=Checkbutton(root,text='Three Years ($3 discount applies)', variable=v3,onvalue=1,bg='white', offvalue=0)
cb3.place(x=575,y=25)
lab1=Label(root,text="(not available for vehicles subject to emissions testing)",font=("ariel",8,"bold"),bg='white')
lab1.place(x=595,y=45)
#frame = Frame(root)
#frame.pack()
reg_period=Label(root,text="Registration Type: ",font=("ariel",11,"bold"),bg='white')
reg_period.place(x=0,y=60)
reg_period=Label(root,text="(check one)",font=("ariel",9),bg='white')
reg_period.place(x=135,y=60)
v4=IntVar()
v5=IntVar()
v6=IntVar()
v7=IntVar()
cb4=Checkbutton(root,text='Original', variable=v4,onvalue=1,bg='white', offvalue=0)
cb4.place(x=240,y=60)
cb5=Checkbutton(root,text='Renewal', variable=v5,onvalue=1,bg='white', offvalue=0)
cb5.place(x=370,y=60)
cb6=Checkbutton(root,text='Private', variable=v6,onvalue=1,bg='white', offvalue=0)
cb6.place(x=520,y=60)
cb7=Checkbutton(root,text='Reissue (plates and decals) ', variable=v7,onvalue=1,bg='white', offvalue=0)
cb7.place(x=690,y=60)
lab2=Label(root,text="See reissue plates below under",bg='white')
lab2.place(x=710,y=80)
lab3=Label(root,text="Plate information",bg='white')
lab3.place(x=710,y=100)
v8=IntVar()
v9=IntVar()
v10=IntVar()
v11=IntVar()
v12=IntVar()
cb8=Checkbutton(root,text='Reissue (Decals Only)', variable=v8,onvalue=1,bg='white', offvalue=0)
cb8.place(x=0,y=90)
cb9=Checkbutton(root,text='Rental vehicle', variable=v9,onvalue=1,bg='white', offvalue=0)
cb9.place(x=240,y=90)
cb10=Checkbutton(root,text='Transfer license plate number: ', variable=v10,onvalue=1,bg='white', offvalue=0)
cb10.place(x=370,y=90)
name_var=StringVar()
name=name_var.get()
name_entry = Entry(root,width='15',textvariable = name_var, font=('calibre',9,'normal'),bg='lightblue')
name_entry.insert(0,"ENTER PLATE NUM")
name_entry.place(x=560,y=90)
def clear_search(event):
    name_entry.delete(0, END)
#name_entry.pack()
name_entry.bind("<Button-1>", clear_search)
cb11=Checkbutton(root,text='For Hire(complete for Hire information) section', variable=v11,onvalue=1,bg='white', offvalue=0)
cb11.place(x=0,y=120)
cb12=Checkbutton(root,text='Ridesharing(Vanpool)(Cannot exceed 16 passengers including driver)  Seating capacity', variable=v12,onvalue=1,bg='white', offvalue=0)
cb12.place(x=370,y=120)
seat_var=StringVar()
seat=seat_var.get()
name_entry01 = Entry(root,width='5',textvariable = seat_var, font=('calibre',10,'normal'),bg='lightblue')
name_entry01.place(x=855,y=120)
v13=IntVar()
v14=IntVar()
cb13=Checkbutton(root,text='Amateur Radio Operator call letters- Specify letters:', variable=v13,onvalue=1,bg='white', offvalue=0)
cb13.place(x=0,y=150)
ama=StringVar()
amateur=ama.get()
name_entry1 = Entry(root,width='10',textvariable = ama, font=('calibre',10,'normal'),bg='lightblue')
name_entry1.place(x=300,y=150)
cb14=Checkbutton(root,text='other:', variable=v14,onvalue=1,bg='white', offvalue=0)
cb14.place(x=500,y=150)
name_var2=StringVar()
name2=name_var2.get()
name_entry2 = Entry(root,width='20',textvariable = name_var2, font=('calibre',9,'normal'),bg='lightblue')
name_entry2.insert(0,"SPECIFY")
name_entry2.place(x=560,y=150)
def clear_search(event):
    name_entry2.delete(0, END)
name_entry2.bind("<Button-1>", clear_search)
reg_info = Label(root,text = "OWNER INFORMATION",width='910',font= ("ariel",11,"bold"),fg = "black",bg='lightgrey')
reg_info.place(x=470,y=200,anchor='center')
v15=IntVar()
v16=IntVar()
owner=Label(root,text="OWNER'S FULL LEGAL NAME OR BUSINESS NAME:",font=("ariel",9),bg='white')
owner.place(x=0,y=215)
name_var3=StringVar()
name3=name_var3.get()
name_entry3 = Entry(root,width='20',textvariable = name_var3, font=('calibre',9,'normal'),bg='lightblue')
name_entry3.place(x=295,y=215)

number=Label(root,text="TELEPHONE NUMBER:",font=("ariel",9),bg='white')
number.place(x=430,y=215)
name_var4=StringVar()
name4=name_var4.get()
name_entry4 = Entry(root,width='10',textvariable = name_var4, font=('calibre',9,'normal'),bg='lightblue')
name_entry4.place(x=570,y=215)

dmv=Label(root,text="DMV CUSTOMER NUMBER/FEIN/SSN",font=("ariel",9),bg='white')
dmv.place(x=670,y=215)
name_var5=StringVar()
name5=name_var5.get()
name_entry5 = Entry(root,width='30',textvariable = name_var5, font=('calibre',9,'normal'),bg='lightblue')
name_entry5.place(x=670,y=235)

coowner=Label(root,text="CO OWNER'S FULL LEGAL NAME:",font=("ariel",9),bg='white')
coowner.place(x=0,y=260)
name_var6=StringVar()
name6=name_var6.get()
name_entry6 = Entry(root,width='35',textvariable = name_var6, font=('calibre',9,'normal'),bg='lightblue')
name_entry6.place(x=200,y=260)

number1=Label(root,text="TELEPHONE NUMBER:",font=("ariel",9),bg='white')
number1.place(x=430,y=260)
name_var7=StringVar()
name7=name_var7.get()
name_entry7 = Entry(root,width='10',textvariable = name_var7, font=('calibre',9,'normal'),bg='lightblue')
name_entry7.place(x=570,y=260)

dmv1=Label(root,text="DMV CUSTOMER NUMBER/FEIN/SSN",font=("ariel",9),bg='white')
dmv1.place(x=670,y=260)
name_var8=StringVar()
name8=name_var8.get()
name_entry8 = Entry(root,width='30',textvariable = name_var8, font=('calibre',9,'normal'),bg='lightblue')
name_entry8.place(x=670,y=280)

resi=Label(root,text="RESIDENCE/BUSINESS JURISDICTION",font=("ariel",9),bg='white')
resi.place(x=670,y=300)
name_var9=StringVar()
name9=name_var9.get()
name_entry9 = Entry(root,width='30',textvariable = name_var9, font=('calibre',9,'normal'),bg='lightblue')
name_entry9.place(x=670,y=320)

note=Label(root,text="NOTE: owners must provide their residence/home/business address where requested, this address",font=("ariel",9),bg='white')
note.place(x=0,y=300)
note1=Label(root,text="cannot be a P.O. box . You must complete your ISD-01 if you would like your address updated.",font=("ariel",9),bg='white')
note1.place(x=0,y=315)

resi1=Label(root,text="OWNER'S RESIDENCE/HOME/BUSINESS ADDRESS:",font=("ariel",9),bg='white')
resi1.place(x=0,y=350)
name_var10=StringVar()
name10=name_var10.get()
name_entry10 = Entry(root,width='45',textvariable = name_var10, font=('calibre',9,'normal'),bg='lightblue')
name_entry10.place(x=0,y=370)

city=Label(root,text="CITY:",font=("ariel",9),bg='white')
city.place(x=370,y=350)
name_var11=StringVar()
name11=name_var11.get()
name_entry11 = Entry(root,width='15',textvariable = name_var11, font=('calibre',9,'normal'),bg='lightblue')
name_entry11.place(x=410,y=350)

state=Label(root,text="STATE:",font=("ariel",9),bg='white')
state.place(x=530,y=350)
name_var12=StringVar()
name12=name_var12.get()
name_entry12 = Entry(root,width='15',textvariable = name_var12, font=('calibre',9,'normal'),bg='lightblue')
name_entry12.place(x=580,y=350)

zipc=Label(root,text="ZIP CODE:",font=("ariel",9),bg='white')
zipc.place(x=715,y=350)
name_var13=StringVar()
name13=name_var13.get()
name_entry13 = Entry(root,width='7',textvariable = name_var13, font=('calibre',9,'normal'),bg='lightblue')
name_entry13.place(x=780,y=350)

resi2=Label(root,text="CO OWNER'S RESIDENCE/HOME/BUSINESS ADDRESS:",font=("ariel",9),bg='white')
resi2.place(x=0,y=390)
name_var14=StringVar()
name14=name_var14.get()
name_entry14 = Entry(root,width='45',textvariable = name_var14, font=('calibre',9,'normal'),bg='lightblue')
name_entry14.place(x=0,y=410)

city=Label(root,text="CITY:",font=("ariel",9),bg='white')
city.place(x=370,y=390)
name_var15=StringVar()
name15=name_var15.get()
name_entry15 = Entry(root,width='15',textvariable = name_var15, font=('calibre',9,'normal'),bg='lightblue')
name_entry15.place(x=410,y=390)

state=Label(root,text="STATE:",font=("ariel",9),bg='white')
state.place(x=530,y=390)
name_var16=StringVar()
name16=name_var16.get()
name_entry16 = Entry(root,width='15',textvariable = name_var16, font=('calibre',9,'normal'),bg='lightblue')
name_entry16.place(x=580,y=390)

zipc=Label(root,text="ZIP CODE:",font=("ariel",9),bg='white')
zipc.place(x=715,y=390)
name_var17=StringVar()
name17=name_var17.get()
name_entry17 = Entry(root,width='7',textvariable = name_var17, font=('calibre',9,'normal'),bg='lightblue')
name_entry17.place(x=780,y=390)

owe=Label(root,text="OWNER EMAIL ADDRESS:",font=("ariel",9),bg='white')
owe.place(x=0,y=435)
name_var018=StringVar()
name018=name_var018.get()
name_entry018 = Entry(root,width='30',textvariable = name_var018, font=('calibre',9,'normal'),bg='lightblue')
name_entry018.place(x=160,y=435)

owe=Label(root,text="CO-OWNER EMAIL ADDRESS:",font=("ariel",9),bg='white')
owe.place(x=420,y=435)
name_var18=StringVar()
name18=name_var18.get()
name_entry18 = Entry(root,width='30',textvariable = name_var18, font=('calibre',9,'normal'),bg='lightblue')
name_entry18.place(x=600,y=435)

add_info = Label(root,text = "REGISTRATION INFORMATION",width='910',font= ("ariel",11,"bold"),fg = "black",bg='lightgrey')
add_info.place(x=470,y=475,anchor='center')

owe=Label(root,text="LOCATION WHERE VEHICLE IS PRINCIPALLY GARAGED:",font=("ariel",9),bg='white')
owe.place(x=0,y=490)
v17=IntVar()
v18=IntVar()
v19=IntVar()
cb17=Checkbutton(root,text='CITY', variable=v17,onvalue=1,bg='white', offvalue=0)
cb17.place(x=0,y=510)
cb18=Checkbutton(root,text='COUNTY', variable=v18,onvalue=1,bg='white', offvalue=0)
cb18.place(x=50,y=510)
cb19=Checkbutton(root,text='TOWN OF', variable=v19,onvalue=1,bg='white', offvalue=0)
cb19.place(x=130,y=510)
name_var19=StringVar()
name19=name_var19.get()
name_entry19 = Entry(root,width='15',textvariable = name_var19, font=('calibre',9,'normal'),bg='lightblue')
name_entry19.place(x=210,y=512)
loc=Label(root,text="IF NEW LOCATION ENTER DATE CHANGED:",font=("ariel",9),bg='white')
loc.place(x=360,y=490)
name_var20=StringVar()
name20=name_var20.get()
name_entry20 = Entry(root,width='15',textvariable = name_var20, font=('calibre',9,'normal'),bg='lightblue')
name_entry20.place(x=500,y=512)
ser=Label(root,text="Are any of the owners/lessees on active",font=("ariel",9),bg='white')
ser.place(x=660,y=490)
ser1=Label(root,text="military duty or services?",font=("ariel",9),bg='white')
ser1.place(x=660,y=510)
v20=IntVar()
v21=IntVar()
v22=IntVar()
cb20=Checkbutton(root,text='YES', variable=v20,onvalue=1,bg='white', offvalue=0)
cb20.place(x=800,y=510)
cb21=Checkbutton(root,text='NO', variable=v21,onvalue=1,bg='white', offvalue=0)
cb21.place(x=850,y=510)
ene=Label(root,text="IF YOU WOULD LIKE YOUR REGISTRATION RENEWALS SENT TO AN ADDRESS OTHER THAN YOUR RESIDENCE/BUSINESS ADDRESS. ENTER IT BELOW",font=("ariel",9),bg='white')
ene.place(x=0,y=535)
mail=Label(root,text="REGISTRATION MAILING ADDRESS-OPTIONAL",font=("ariel",9),bg='white')
mail.place(x=0,y=558)
name_var21=StringVar()
name21=name_var21.get()
name_entry21 = Entry(root,width='20',textvariable = name_var21, font=('calibre',9,'normal'),bg='lightblue')
name_entry21.place(x=270,y=558)
cit=Label(root,text="CITY",font=("ariel",9),bg='white')
cit.place(x=440,y=558)
name_var22=StringVar()
name22=name_var22.get()
name_entry22 = Entry(root,width='12',textvariable = name_var22, font=('calibre',9,'normal'),bg='lightblue')
name_entry22.place(x=475,y=558)

sta=Label(root,text="STATE",font=("ariel",9),bg='white')
sta.place(x=590,y=558)
name_var23=StringVar()
name23=name_var23.get()
name_entry23 = Entry(root,width='12',textvariable = name_var23, font=('calibre',9,'normal'),bg='lightblue')
name_entry23.place(x=635,y=558)

zi=Label(root,text="ZIP CODE",font=("ariel",9),bg='white')
zi.place(x=730,y=558)
name_var24=StringVar()
name24=name_var24.get()
name_entry24 = Entry(root,width='8',textvariable = name_var24, font=('calibre',9,'normal'),bg='lightblue')
name_entry24.place(x=795,y=558)

  
excel()
submit=Button(text="SUBMIT",fg='blue',bg='lightgreen',font=('calibre',13,'bold'),width='10',command=insert)
submit.place(x=400,y=600)
root.mainloop()
